# %% [markdown]
# <a href="https://colab.research.google.com/github/Shravan1711/Data-Science-Assignments/blob/main/Pandas%20Library%20Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
a=pd.Series([100,200,300,400])
print(a,type(a))
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# dtype: int64 <class 'pandas.core.series.Series'>

# %%
print(a[2])
# Out:
# 300

# %%
a=pd.Series([100,200,300,400],index=['c','a','b','d'])
print(a)
# Out:
# c    100
# a    200
# b    300
# d    400
# dtype: int64

# %%
a['d']
# Out:
# 400

# %%
b=pd.Series([800,450,100],index=['e','f','g'])
b
# Out:
# e    800
# f    450
# g    100
# dtype: int64

# %%
a=a.append(b)

# %%
print(a)
# Out:
# c    100
# a    200
# b    300
# d    400
# e    800
# f    450
# g    100
# dtype: int64

# %%
a.sort_values(ascending=False)
# Out:
# e    800
# f    450
# d    400
# b    300
# a    200
# c    100
# g    100
# dtype: int64

# %%
a=a.index
a
# Out:
# Index(['c', 'a', 'b', 'd', 'e', 'f', 'g'], dtype='object')

# %%
df=pd.DataFrame(a)
df
# Out:
#    0
# 0  c
# 1  a
# 2  b
# 3  d
# 4  e
# 5  f
# 6  g

# %%
df.shape
# Out:
# (7, 1)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
df.head()
# Out:
#    0
# 0  c
# 1  a
# 2  b
# 3  d
# 4  e

# %%
df.tail()
# Out:
#    0
# 2  b
# 3  d
# 4  e
# 5  f
# 6  g

# %% [markdown]
# .head() prints the first 5 elements.
#
# .tail() prints the last 5 elements.

# %%
df.columns = ['points']
df
# Out:
#   points
# 0      c
# 1      a
# 2      b
# 3      d
# 4      e
# 5      f
# 6      g

# %%
fruits=pd.DataFrame(['orange','mango','apple','mango','orange','apple','orange'])
fruits
# Out:
#         0
# 0  orange
# 1   mango
# 2   apple
# 3   mango
# 4  orange
# 5   apple
# 6  orange

# %%
df['fruits']=['orange','mango','apple','mango','orange','apple','orange']
df
# Out:
#   points  fruits
# 0      c  orange
# 1      a   mango
# 2      b   apple
# 3      d   mango
# 4      e  orange
# 5      f   apple
# 6      g  orange

# %%
d1 =pd.DataFrame({'city':['Chandigarh','Delhi','Kanpur','Chennai','Manali'],
       'Temperature':[15,22,20,25,-2]})
d1
# Out:
#          city  Temperature
# 0  Chandigarh           15
# 1       Delhi           22
# 2      Kanpur           20
# 3     Chennai           25
# 4      Manali           -2

# %%
d1.shape
# Out:
# (5, 2)

# %%
city=d1['city']
city
# Out:
# 0    Chandigarh
# 1         Delhi
# 2        Kanpur
# 3       Chennai
# 4        Manali
# Name: city, dtype: object

# %%
type(city)
# Out:
# pandas.core.series.Series

# %%
d2 = pd.DataFrame({'city':['Bangalure','Coimbatore','Srirangam','Pondicherry'],
                   'Temperature':[24,35,36,39]})
d2
# Out:
#           city  Temperature
# 0    Bangalure           24
# 1   Coimbatore           35
# 2    Srirangam           36
# 3  Pondicherry           39

# %%
d2.shape
# Out:
# (4, 2)

# %%
d3=pd.concat([d1,d2],axis=0)
d3
# Out:
#           city  Temperature
# 0   Chandigarh           15
# 1        Delhi           22
# 2       Kanpur           20
# 3      Chennai           25
# 4       Manali           -2
# 0    Bangalure           24
# 1   Coimbatore           35
# 2    Srirangam           36
# 3  Pondicherry           39

# %%
d3[d3['Temperature']<=20][['city']]
# Out:
#          city
# 0  Chandigarh
# 2      Kanpur
# 4      Manali

# %%
d3[d3['Temperature']>=35][['city']]
# Out:
#           city
# 1   Coimbatore
# 2    Srirangam
# 3  Pondicherry

# %%
def is_ut(x):
  if x in ['Chandigarh','Pondicherry','Delhi']:
    return True
  else:
    return False

# %%
d3['is_ut']=is_ut('city')
d3
# Out:
#           city  Temperature  is_ut
# 0   Chandigarh           15  False
# 1        Delhi           22  False
# 2       Kanpur           20  False
# 3      Chennai           25  False
# 4       Manali           -2  False
# 0    Bangalure           24  False
# 1   Coimbatore           35  False
# 2    Srirangam           36  False
# 3  Pondicherry           39  False

# %%
data=pd.DataFrame({'Student':[1,2,3,4,5],
                   'Marks':[10,20,30,40,50]})
data
# Out:
#    Student  Marks
# 0        1     10
# 1        2     20
# 2        3     30
# 3        4     40
# 4        5     50

# %%
data.groupby(['Marks']).sum()
# Out:
#        Student
# Marks
# 10           1
# 20           2
# 30           3
# 40           4
# 50           5

# %%
data.groupby(['Marks']).count()
# Out:
#        Student
# Marks
# 10           1
# 20           1
# 30           1
# 40           1
# 50           1

# %%
data.groupby(['Student','Marks']).mean()
# Out:
# Empty DataFrame
# Columns: []
# Index: [(1, 10), (2, 20), (3, 30), (4, 40), (5, 50)]

# %%
a=pd.date_range(start='2020-01-01',end='2021-04-01')
a
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10',
#                ...
#                '2021-03-23', '2021-03-24', '2021-03-25', '2021-03-26',
#                '2021-03-27', '2021-03-28', '2021-03-29', '2021-03-30',
#                '2021-03-31', '2021-04-01'],
#               dtype='datetime64[ns]', length=457, freq='D')

# %%
len(a)
# Out:
# 457

# %%
type(a)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex
